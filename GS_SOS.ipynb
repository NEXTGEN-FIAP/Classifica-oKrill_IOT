# %%
# !pip install roboflow
from roboflow import Roboflow

# Instanciação da classe Roboflow com a chave da API fornecida
rf = Roboflow(api_key="rx4eN0XVSONmEKZ4xvxX")

# Acesso ao projeto "krill" no espaço de trabalho do Roboflow
project = rf.workspace().project("krill")

# Seleção da versão 2 do modelo no projeto
model = project.version(3).model

# Realização de previsões na imagem localizada em "/content/OIP.jpg" com uma confiança mínima de 40%
# Não passando o argumento "overlap"
print(model.predict("/content/R.jpg", confidence=40).json())

# Salvamento da imagem de previsão como "prediction.jpg"
model.predict("/content/R.jpg", confidence=40).save("prediction.jpg")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
